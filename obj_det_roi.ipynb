# %%
from ultralytics import YOLO
import cv2
import os
import time

def iou(boxA, boxB):
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])
    interArea = max(0, xB - xA) * max(0, yB - yA)  # Area of intersection
    boxAArea = (boxA[2] - boxA[0]) * (boxA[3] - boxA[1])  # Area of boxA
    boxBArea = (boxB[2] - boxB[0]) * (boxB[3] - boxB[1])  # Area of boxB
    if boxAArea == 0 or boxBArea == 0:
        return 0.0
    return interArea / float(boxAArea + boxBArea - interArea)

# ------------------------------------------------------------
# Configuration
# ------------------------------------------------------------
model_path = r"C:\Users\joshu\Documents\EEE\AMNIS\Models\training\weights\best.pt"
video_path = r"C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4"
save_dir = r"C:\Users\joshu\Documents\EEE\AMNIS\output_videos"
os.makedirs(save_dir, exist_ok=True)

# Detection thresholds
detection_conf_thresh = 0.1    # Confidence threshold for YOLO detections
detection_nms_thresh = 0.5     # NMS IOU threshold for YOLO detections

# Tracking thresholds
tracking_iou_thresh = 0.5      # IOU threshold for object tracking/matching
shelf_thresh = 100            # Vertical distance threshold for shelf grouping
lost_time_limit = 300         # Frames before declaring object as permanently lost

tracker_config = 'bytetrack.yaml'

# Initialize video capture to get frame for ROI selection
cap = cv2.VideoCapture(video_path)
ret, first_frame = cap.read()
if not ret:
    raise RuntimeError("Could not read first frame")

# Get ROI from user
print("Select ROI and press ENTER. Press C to cancel.")
roi = cv2.selectROI("Select ROI", first_frame, fromCenter=False, showCrosshair=True)
cv2.destroyWindow("Select ROI")
x_min, y_min, w, h = roi
x_max, y_max = x_min + w, y_min + h

# Get video properties
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
cap.release()

# Load YOLO model
model = YOLO(model_path)

# Initialize the tracking generator
generator = model.track(
    source=video_path,
    imgsz=640,
    conf=detection_conf_thresh,
    iou=detection_nms_thresh,
    tracker=tracker_config,
    stream=True
)

# Prepare video writer
output_video_path = os.path.join(save_dir, "tracked_with_roi.mp4")
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out_writer = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

# State management
active_objects = []      # List of (label, box) tuples for current objects
lost_objects = {}        # Dict of label: (box, last_seen_frame) for lost objects
next_label_num = 1      # Counter for generating unique object labels
objects_that_left = set()  # Set of labels for objects that have left the scene
frame_count = 0
box_color = (0, 255, 0)

# Main processing loop
while True:
    try:
        results = next(generator)
    except StopIteration:
        break

    frame_count += 1
    frame = results.orig_img.copy()

    # Filter boxes to only include those within ROI
    boxes = []
    for b in results.boxes:
        x1, y1, x2, y2 = map(int, b.xyxy[0])
        if (x_min <= x1 <= x_max and x_min <= x2 <= x_max and
            y_min <= y1 <= y_max and y_min <= y2 <= y_max):
            boxes.append((x1, y1, x2, y2))

    if boxes:
        # Group boxes into shelves
        boxes.sort(key=lambda b: b[3])
        shelves = []
        for bx in boxes:
            x1, y1, x2, y2 = bx
            placed = False
            for shelf in shelves:
                shelf_bottoms = [b[3] for b in shelf]
                shelf_mean_bottom = sum(shelf_bottoms) / len(shelf_bottoms)
                if abs(y2 - shelf_mean_bottom) <= shelf_thresh:
                    shelf.append(bx)
                    placed = True
                    break
            if not placed:
                shelves.append([bx])

        # Sort shelves and create final box list
        for shelf in shelves:
            shelf.sort(key=lambda b: b[0])
        sorted_boxes = [b for shelf in shelves for b in shelf]

        # Track objects
        new_objects = []
        used_active_labels = set()

        for new_box in sorted_boxes:
            # Try to match with active objects
            best_iou = 0
            best_label = None
            for (lbl, a_box) in active_objects:
                iou_val = iou(a_box, new_box)
                if iou_val > best_iou:
                    best_iou = iou_val
                    best_label = lbl

            if best_iou > tracking_iou_thresh:
                new_objects.append((best_label, new_box))
                used_active_labels.add(best_label)
            else:
                # Try to match with lost objects
                best_iou_lost = 0
                best_lost_label = None
                for lbl, (l_box, l_frame) in lost_objects.items():
                    if frame_count - l_frame <= lost_time_limit:
                        iou_val = iou(l_box, new_box)
                        if iou_val > best_iou_lost:
                            best_iou_lost = iou_val
                            best_lost_label = lbl

                if best_iou_lost > tracking_iou_thresh and best_lost_label is not None:
                    new_objects.append((best_lost_label, new_box))
                    used_active_labels.add(best_lost_label)
                    del lost_objects[best_lost_label]
                    objects_that_left.discard(best_lost_label)
                else:
                    new_objects.append((next_label_num, new_box))
                    used_active_labels.add(next_label_num)
                    next_label_num += 1

        # Handle disappeared objects
        active_labels = {lbl for (lbl, _) in active_objects}
        disappeared = active_labels - used_active_labels
        for lbl in disappeared:
            for (l, box) in active_objects:
                if l == lbl:
                    lost_objects[lbl] = (box, frame_count)
                    objects_that_left.add(lbl)

        # Clean up lost objects
        lost_objects = {
            lbl: (box, frame) 
            for lbl, (box, frame) in lost_objects.items() 
            if frame_count - frame <= lost_time_limit
        }

        active_objects = new_objects

        # Draw visualizations
        # Draw ROI
        cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), (255, 0, 0), 2)

        # Draw bounding boxes and labels
        for (lbl, (x1, y1, x2, y2)) in active_objects:
            cv2.rectangle(frame, (x1, y1), (x2, y2), box_color, 2)
            cv2.putText(frame, f"{lbl}", (x1 + 5, y1 + 20), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.7, box_color, 2)

        # Draw shelf boundaries
        for idx, shelf in enumerate(shelves, start=1):
            y = min(b[3] for b in shelf)
            cv2.line(frame, (0, y), (width, y), (0, 0, 255), 2)
            cv2.putText(frame, f"Shelf {idx}", (10, y - 10), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

        # Draw status information
        if objects_that_left:
            text = f"Objects that have left: {', '.join(map(str, objects_that_left))}"
            cv2.putText(frame, text, (100, 90), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)

        cv2.putText(frame, f"Total objects in scene: {len(active_objects)}", 
                   (100, 45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    else:
        # Handle case when no boxes are detected
        for (lbl, box) in active_objects:
            lost_objects[lbl] = (box, frame_count)
            objects_that_left.add(lbl)
        active_objects = []

    out_writer.write(frame)

out_writer.release()
print(f"Processed video saved to {output_video_path}")

# Automatically play the processed video
def play_video(video_path):
    cap = cv2.VideoCapture(video_path)
    
    # Get video properties
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    frame_delay = int(1000/fps)  # Convert fps to milliseconds delay between frames
    
    while True:
        ret, frame = cap.read()
        if not ret:
            break
            
        cv2.imshow('Processed Video', frame)
        
        # Break loop if 'q' is pressed or window is closed
        key = cv2.waitKey(frame_delay) & 0xFF
        if key == ord('q') or cv2.getWindowProperty('Processed Video', cv2.WND_PROP_VISIBLE) < 1:
            break
    
    cap.release()
    cv2.destroyAllWindows()

# Play the processed video
print("Playing processed video (press 'q' to quit)...")
play_video(output_video_path)
# Out:
# Select ROI and press ENTER. Press C to cancel.
#
# video 1/1 (frame 1/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 19.5ms
# video 1/1 (frame 2/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 21.2ms
# video 1/1 (frame 3/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 20.0ms
# video 1/1 (frame 4/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 21.0ms
# video 1/1 (frame 5/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 19.1ms
# video 1/1 (frame 6/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 19.5ms
# video 1/1 (frame 7/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 20.0ms
# video 1/1 (frame 8/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 18.5ms
# video 1/1 (frame 9/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 18.0ms
# video 1/1 (frame 10/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 19.0ms
# video 1/1 (frame 11/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 20.5ms
# video 1/1 (frame 12/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 19.0ms
# video 1/1 (frame 13/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 16.6ms
# video 1/1 (frame 14/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 21.0ms
# video 1/1 (frame 15/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 18.1ms
# video 1/1 (frame 16/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 17.5ms
# video 1/1 (frame 17/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 18.7ms
# video 1/1 (frame 18/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 18.0ms
# video 1/1 (frame 19/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 19.1ms
# video 1/1 (frame 20/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 17.6ms
# video 1/1 (frame 21/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 17.0ms
# video 1/1 (frame 22/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 18.0ms
# video 1/1 (frame 23/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 17.5ms
# video 1/1 (frame 24/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 18.5ms
# video 1/1 (frame 25/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 17.5ms
# video 1/1 (frame 26/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 18.4ms
# video 1/1 (frame 27/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 18.6ms
# video 1/1 (frame 28/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 18.4ms
# video 1/1 (frame 29/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 19.0ms
# video 1/1 (frame 30/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 17.2ms
# video 1/1 (frame 31/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 17.1ms
# video 1/1 (frame 32/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 17.0ms
# video 1/1 (frame 33/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 17.5ms
# video 1/1 (frame 34/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 17.6ms
# video 1/1 (frame 35/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 16.5ms
# video 1/1 (frame 36/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 17.4ms
# video 1/1 (frame 37/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 17.6ms
# video 1/1 (frame 38/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 18.0ms
# video 1/1 (frame 39/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 16.0ms
# video 1/1 (frame 40/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 16.6ms
# video 1/1 (frame 41/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 17.5ms
# video 1/1 (frame 42/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 16.0ms
# video 1/1 (frame 43/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 16.6ms
# video 1/1 (frame 44/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 16.6ms
# video 1/1 (frame 45/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 16.6ms
# video 1/1 (frame 46/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 17.2ms
# video 1/1 (frame 47/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 15.4ms
# video 1/1 (frame 48/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 15.9ms
# video 1/1 (frame 49/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 19.0ms
# video 1/1 (frame 50/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 16.0ms
# video 1/1 (frame 51/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 17.5ms
# video 1/1 (frame 52/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 16.0ms
# video 1/1 (frame 53/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 17.1ms
# video 1/1 (frame 54/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 17.5ms
# video 1/1 (frame 55/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 16.5ms
# video 1/1 (frame 56/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 16.5ms
# video 1/1 (frame 57/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 14.5ms
# video 1/1 (frame 58/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 16.0ms
# video 1/1 (frame 59/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 15.5ms
# video 1/1 (frame 60/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 17.0ms
# video 1/1 (frame 61/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 15.0ms
# video 1/1 (frame 62/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 16.2ms
# video 1/1 (frame 63/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 15.5ms
# video 1/1 (frame 64/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 16.5ms
# video 1/1 (frame 65/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 9.0ms
# video 1/1 (frame 66/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.7ms
# video 1/1 (frame 67/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.7ms
# video 1/1 (frame 68/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.5ms
# video 1/1 (frame 69/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 70/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.3ms
# video 1/1 (frame 71/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.1ms
# video 1/1 (frame 72/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 73/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 74/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.5ms
# video 1/1 (frame 75/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.3ms
# video 1/1 (frame 76/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 77/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 78/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.5ms
# video 1/1 (frame 79/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.2ms
# video 1/1 (frame 80/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 81/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 82/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 83/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 9.0ms
# video 1/1 (frame 84/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 15 obs, 9.0ms
# video 1/1 (frame 85/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 15 obs, 8.0ms
# video 1/1 (frame 86/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 15 obs, 8.0ms
# video 1/1 (frame 87/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 88/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 15 obs, 9.1ms
# video 1/1 (frame 89/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 15 obs, 9.0ms
# video 1/1 (frame 90/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 15 obs, 9.0ms
# video 1/1 (frame 91/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 15 obs, 8.7ms
# video 1/1 (frame 92/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 15 obs, 7.5ms
# video 1/1 (frame 93/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 15 obs, 8.6ms
# video 1/1 (frame 94/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 15 obs, 9.2ms
# video 1/1 (frame 95/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 14 obs, 8.5ms
# video 1/1 (frame 96/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 14 obs, 8.4ms
# video 1/1 (frame 97/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 14 obs, 7.4ms
# video 1/1 (frame 98/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 14 obs, 7.9ms
# video 1/1 (frame 99/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 13 obs, 7.5ms
# video 1/1 (frame 100/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 13 obs, 8.0ms
# video 1/1 (frame 101/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 13 obs, 7.5ms
# video 1/1 (frame 102/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 14 obs, 8.0ms
# video 1/1 (frame 103/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 14 obs, 7.5ms
# video 1/1 (frame 104/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 14 obs, 9.8ms
# video 1/1 (frame 105/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 14 obs, 7.5ms
# video 1/1 (frame 106/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 15 obs, 8.5ms
# video 1/1 (frame 107/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 15 obs, 8.0ms
# video 1/1 (frame 108/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 15 obs, 7.5ms
# video 1/1 (frame 109/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 14 obs, 7.5ms
# video 1/1 (frame 110/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 14 obs, 7.5ms
# video 1/1 (frame 111/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 15 obs, 8.0ms
# video 1/1 (frame 112/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 15 obs, 8.1ms
# video 1/1 (frame 113/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 15 obs, 7.5ms
# video 1/1 (frame 114/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 15 obs, 8.2ms
# video 1/1 (frame 115/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.0ms
# video 1/1 (frame 116/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 117/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.7ms
# video 1/1 (frame 118/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.5ms
# video 1/1 (frame 119/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 120/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 121/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 122/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 123/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 124/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.0ms
# video 1/1 (frame 125/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 126/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 127/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 128/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 129/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 130/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.1ms
# video 1/1 (frame 131/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 9.0ms
# video 1/1 (frame 132/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.2ms
# video 1/1 (frame 133/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 134/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.0ms
# video 1/1 (frame 135/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 136/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 137/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 138/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 139/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.0ms
# video 1/1 (frame 140/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.5ms
# video 1/1 (frame 141/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 142/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 9.6ms
# video 1/1 (frame 143/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 144/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.0ms
# video 1/1 (frame 145/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 146/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 147/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 148/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.0ms
# video 1/1 (frame 149/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 150/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 151/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.5ms
# video 1/1 (frame 152/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.0ms
# video 1/1 (frame 153/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.5ms
# video 1/1 (frame 154/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 155/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.5ms
# video 1/1 (frame 156/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 157/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 6.5ms
# video 1/1 (frame 158/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.4ms
# video 1/1 (frame 159/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 6.9ms
# video 1/1 (frame 160/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 161/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.4ms
# video 1/1 (frame 162/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 163/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 6.4ms
# video 1/1 (frame 164/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 9.0ms
# video 1/1 (frame 165/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.3ms
# video 1/1 (frame 166/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.5ms
# video 1/1 (frame 167/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 168/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 169/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.2ms
# video 1/1 (frame 170/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 171/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.6ms
# video 1/1 (frame 172/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 173/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.1ms
# video 1/1 (frame 174/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.5ms
# video 1/1 (frame 175/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 176/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 177/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 178/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 179/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.3ms
# video 1/1 (frame 180/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.7ms
# video 1/1 (frame 181/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.0ms
# video 1/1 (frame 182/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 183/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.0ms
# video 1/1 (frame 184/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.6ms
# video 1/1 (frame 185/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 186/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 187/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 6.5ms
# video 1/1 (frame 188/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 6.5ms
# video 1/1 (frame 189/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 190/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 191/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.1ms
# video 1/1 (frame 192/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.0ms
# video 1/1 (frame 193/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 194/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 195/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 6.5ms
# video 1/1 (frame 196/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 6.9ms
# video 1/1 (frame 197/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 6.5ms
# video 1/1 (frame 198/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.0ms
# video 1/1 (frame 199/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.1ms
# video 1/1 (frame 200/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.0ms
# video 1/1 (frame 201/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 7.5ms
# video 1/1 (frame 202/202) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_105738_BR0.mp4: 384x640 16 obs, 8.5ms
# Speed: 1.0ms preprocess, 10.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed video saved to C:\Users\joshu\Documents\EEE\AMNIS\output_videos\tracked_with_roi.mp4
# Playing processed video (press 'q' to quit)...
