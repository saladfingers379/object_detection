# %%
from ultralytics import YOLO
import cv2
import os
import time

def iou(boxA, boxB):
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])
    interArea = max(0, xB - xA) * max(0, yB - yA)  # Area of intersection
    boxAArea = (boxA[2] - boxA[0]) * (boxA[3] - boxA[1])  # Area of boxA
    boxBArea = (boxB[2] - boxB[0]) * (boxB[3] - boxB[1])  # Area of boxB
    if boxAArea == 0 or boxBArea == 0:
        return 0.0
    return interArea / float(boxAArea + boxBArea - interArea)

# ------------------------------------------------------------
# Configuration
# ------------------------------------------------------------
model_path = r"C:\Users\joshu\Documents\EEE\AMNIS\Models\training\weights\best.pt"
video_path = r"C:\Users\joshu\Downloads\before and after vid.mp4"
save_dir = r"C:\Users\joshu\Documents\EEE\AMNIS\output_videos"
os.makedirs(save_dir, exist_ok=True)

# Detection thresholds
detection_conf_thresh = 0.4   # Confidence threshold for YOLO detections
detection_nms_thresh = 0.05     # NMS IOU threshold for YOLO detections

# Tracking thresholds
tracking_iou_thresh = 0.5      # IOU threshold for object tracking/matching
shelf_thresh = 100            # Vertical distance threshold for shelf grouping
lost_time_limit = 500        # Frames before declaring object as permanently lost

tracker_config = 'bytetrack.yaml'

# Initialize video capture to get frame for ROI selection
cap = cv2.VideoCapture(video_path)
ret, first_frame = cap.read()
if not ret:
    raise RuntimeError("Could not read first frame")

# Get ROI from user
print("Select ROI and press ENTER. Press C to cancel.")
roi = cv2.selectROI("Select ROI", first_frame, fromCenter=False, showCrosshair=True)
cv2.destroyWindow("Select ROI")
x_min, y_min, w, h = roi
x_max, y_max = x_min + w, y_min + h

# Get video properties
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
cap.release()

# Load YOLO model
model = YOLO(model_path)

# Initialize the tracking generator
generator = model.track(
    source=video_path,
    imgsz=640,
    conf=detection_conf_thresh,
    iou=detection_nms_thresh,
    tracker=tracker_config,
    stream=True
)

# Prepare video writer
output_video_path = os.path.join(save_dir, "before_after_640.mp4")
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out_writer = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

# State management
active_objects = []      # List of (label, box) tuples for current objects
lost_objects = {}        # Dict of label: (box, last_seen_frame) for lost objects
next_label_num = 1      # Counter for generating unique object labels
objects_that_left = set()  # Set of labels for objects that have left the scene
frame_count = 0
box_color = (0, 255, 0)

# Main processing loop
while True:
    try:
        results = next(generator)
    except StopIteration:
        break

    frame_count += 1
    frame = results.orig_img.copy()

    # Filter boxes to only include those within ROI
    boxes = []
    for b in results.boxes:
        x1, y1, x2, y2 = map(int, b.xyxy[0])
        if (x_min <= x1 <= x_max and x_min <= x2 <= x_max and
            y_min <= y1 <= y_max and y_min <= y2 <= y_max):
            boxes.append((x1, y1, x2, y2))

    if boxes:
        # Group boxes into shelves
        boxes.sort(key=lambda b: b[3])
        shelves = []
        for bx in boxes:
            x1, y1, x2, y2 = bx
            placed = False
            for shelf in shelves:
                shelf_bottoms = [b[3] for b in shelf]
                shelf_mean_bottom = sum(shelf_bottoms) / len(shelf_bottoms)
                if abs(y2 - shelf_mean_bottom) <= shelf_thresh:
                    shelf.append(bx)
                    placed = True
                    break
            if not placed:
                shelves.append([bx])

        # Sort shelves and create final box list
        for shelf in shelves:
            shelf.sort(key=lambda b: b[0])
        sorted_boxes = [b for shelf in shelves for b in shelf]

        # Track objects
        new_objects = []
        used_active_labels = set()

        for new_box in sorted_boxes:
            # Try to match with active objects
            best_iou = 0
            best_label = None
            for (lbl, a_box) in active_objects:
                iou_val = iou(a_box, new_box)
                if iou_val > best_iou:
                    best_iou = iou_val
                    best_label = lbl

            if best_iou > tracking_iou_thresh:
                new_objects.append((best_label, new_box))
                used_active_labels.add(best_label)
            else:
                # Try to match with lost objects
                best_iou_lost = 0
                best_lost_label = None
                for lbl, (l_box, l_frame) in lost_objects.items():
                    if frame_count - l_frame <= lost_time_limit:
                        iou_val = iou(l_box, new_box)
                        if iou_val > best_iou_lost:
                            best_iou_lost = iou_val
                            best_lost_label = lbl

                if best_iou_lost > tracking_iou_thresh and best_lost_label is not None:
                    new_objects.append((best_lost_label, new_box))
                    used_active_labels.add(best_lost_label)
                    del lost_objects[best_lost_label]
                    objects_that_left.discard(best_lost_label)
                else:
                    new_objects.append((next_label_num, new_box))
                    used_active_labels.add(next_label_num)
                    next_label_num += 1

        # Handle disappeared objects
        active_labels = {lbl for (lbl, _) in active_objects}
        disappeared = active_labels - used_active_labels
        for lbl in disappeared:
            for (l, box) in active_objects:
                if l == lbl:
                    lost_objects[lbl] = (box, frame_count)
                    objects_that_left.add(lbl)

        # Clean up lost objects
        lost_objects = {
            lbl: (box, frame) 
            for lbl, (box, frame) in lost_objects.items() 
            if frame_count - frame <= lost_time_limit
        }

        active_objects = new_objects

        # Draw visualizations
        # Draw ROI
        cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), (255, 0, 0), 2)

        # Draw bounding boxes and labels
        for (lbl, (x1, y1, x2, y2)) in active_objects:
            cv2.rectangle(frame, (x1, y1), (x2, y2), box_color, 2)
            cv2.putText(frame, f"{lbl}", (x1 + 5, y1 + 20), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.7, box_color, 2)

        # Draw shelf boundaries
        for idx, shelf in enumerate(shelves, start=1):
            y = min(b[3] for b in shelf)
            cv2.line(frame, (0, y), (width, y), (0, 0, 255), 2)
            cv2.putText(frame, f"Shelf {idx}", (10, y - 10), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

        # Draw status information
        if objects_that_left:
            text = f"Objects that have left: {', '.join(map(str, objects_that_left))}"
            cv2.putText(frame, text, (100, 90), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)

        cv2.putText(frame, f"Total objects in scene: {len(active_objects)}", 
                   (100, 45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    else:
        # Handle case when no boxes are detected
        for (lbl, box) in active_objects:
            lost_objects[lbl] = (box, frame_count)
            objects_that_left.add(lbl)
        active_objects = []

    out_writer.write(frame)

out_writer.release()
print(f"Processed video saved to {output_video_path}")

# Automatically play the processed video
def play_video(video_path):
    cap = cv2.VideoCapture(video_path)
    
    # Get video properties
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    frame_delay = int(1000/fps)  # Convert fps to milliseconds delay between frames
    
    while True:
        ret, frame = cap.read()
        if not ret:
            break
            
        cv2.imshow('Processed Video', frame)
        
        # Break loop if 'q' is pressed or window is closed
        key = cv2.waitKey(frame_delay) & 0xFF
        if key == ord('q') or cv2.getWindowProperty('Processed Video', cv2.WND_PROP_VISIBLE) < 1:
            break
    
    cap.release()
    cv2.destroyAllWindows()

# Play the processed video
print("Playing processed video (press 'q' to quit)...")
play_video(output_video_path)
# Out:
# Select ROI and press ENTER. Press C to cancel.
#
# video 1/1 (frame 1/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 29 obs, 36.6ms
# video 1/1 (frame 2/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 29 obs, 11.5ms
# video 1/1 (frame 3/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 29 obs, 8.5ms
# video 1/1 (frame 4/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 29 obs, 10.5ms
# video 1/1 (frame 5/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 29 obs, 11.1ms
# video 1/1 (frame 6/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 29 obs, 8.0ms
# video 1/1 (frame 7/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 29 obs, 7.9ms
# video 1/1 (frame 8/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 29 obs, 9.5ms
# video 1/1 (frame 9/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 29 obs, 9.7ms
# video 1/1 (frame 10/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 29 obs, 11.3ms
# video 1/1 (frame 11/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 29 obs, 8.6ms
# video 1/1 (frame 12/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 29 obs, 10.1ms
# video 1/1 (frame 13/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 29 obs, 9.6ms
# video 1/1 (frame 14/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 29 obs, 8.6ms
# video 1/1 (frame 15/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 29 obs, 8.2ms
# video 1/1 (frame 16/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 29 obs, 8.4ms
# video 1/1 (frame 17/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 29 obs, 8.2ms
# video 1/1 (frame 18/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 29 obs, 8.6ms
# video 1/1 (frame 19/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 29 obs, 8.5ms
# video 1/1 (frame 20/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 29 obs, 8.7ms
# video 1/1 (frame 21/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 9.3ms
# video 1/1 (frame 22/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 9.9ms
# video 1/1 (frame 23/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 8.6ms
# video 1/1 (frame 24/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 8.4ms
# video 1/1 (frame 25/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 8.8ms
# video 1/1 (frame 26/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 8.0ms
# video 1/1 (frame 27/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 8.7ms
# video 1/1 (frame 28/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 8.5ms
# video 1/1 (frame 29/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 7.5ms
# video 1/1 (frame 30/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 8.5ms
# video 1/1 (frame 31/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 7.5ms
# video 1/1 (frame 32/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 7.4ms
# video 1/1 (frame 33/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 7.1ms
# video 1/1 (frame 34/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 8.7ms
# video 1/1 (frame 35/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 7.5ms
# video 1/1 (frame 36/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 8.6ms
# video 1/1 (frame 37/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 7.9ms
# video 1/1 (frame 38/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 7.5ms
# video 1/1 (frame 39/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 7.8ms
# video 1/1 (frame 40/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 8.5ms
# video 1/1 (frame 41/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 8.0ms
# video 1/1 (frame 42/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 7.5ms
# video 1/1 (frame 43/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 9.0ms
# video 1/1 (frame 44/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 9.0ms
# video 1/1 (frame 45/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 7.5ms
# video 1/1 (frame 46/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 7.3ms
# video 1/1 (frame 47/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 11.1ms
# video 1/1 (frame 48/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 9.9ms
# video 1/1 (frame 49/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 8.2ms
# video 1/1 (frame 50/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 9.0ms
# video 1/1 (frame 51/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 7.2ms
# video 1/1 (frame 52/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 8.5ms
# video 1/1 (frame 53/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 8.5ms
# video 1/1 (frame 54/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 9.5ms
# video 1/1 (frame 55/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 8.0ms
# video 1/1 (frame 56/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 10.2ms
# video 1/1 (frame 57/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 8.4ms
# video 1/1 (frame 58/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 9.0ms
# video 1/1 (frame 59/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 8.6ms
# video 1/1 (frame 60/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 8.0ms
# video 1/1 (frame 61/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 7.8ms
# video 1/1 (frame 62/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 7.5ms
# video 1/1 (frame 63/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 8.8ms
# video 1/1 (frame 64/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 8.1ms
# video 1/1 (frame 65/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 9.9ms
# video 1/1 (frame 66/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 7.3ms
# video 1/1 (frame 67/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 8.0ms
# video 1/1 (frame 68/68) C:\Users\joshu\Downloads\before and after vid.mp4: 384x640 28 obs, 9.0ms
# Speed: 0.8ms preprocess, 9.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed video saved to C:\Users\joshu\Documents\EEE\AMNIS\output_videos\before_after_640.mp4
# Playing processed video (press 'q' to quit)...

# %%
#trying canny edge detection in the preprocessing

from ultralytics import YOLO
import cv2
import os
import time
import numpy as np

def iou(boxA, boxB):
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])
    interArea = max(0, xB - xA) * max(0, yB - yA)  # Area of intersection
    boxAArea = (boxA[2] - boxA[0]) * (boxA[3] - boxA[1])  # Area of boxA
    boxBArea = (boxB[2] - boxB[0]) * (boxB[3] - boxB[1])  # Area of boxB
    if boxAArea == 0 or boxBArea == 0:
        return 0.0
    return interArea / float(boxAArea + boxBArea - interArea)

# ------------------------------------------------------------
# Configuration
# ------------------------------------------------------------
model_path = r"C:\Users\joshu\Documents\EEE\AMNIS\Models\training\weights\best.pt"
video_path = r"C:\Users\joshu\Downloads\before and after vid.mp4"
save_dir = r"C:\Users\joshu\Documents\EEE\AMNIS\output_videos"
os.makedirs(save_dir, exist_ok=True)

# Detection thresholds
detection_conf_thresh = 0.02   # Confidence threshold for YOLO detections
detection_nms_thresh = 0.05     # NMS IOU threshold for YOLO detections

# Tracking thresholds
tracking_iou_thresh = 0.5      # IOU threshold for object tracking/matching
shelf_thresh = 100            # Vertical distance threshold for shelf grouping
lost_time_limit = 500        # Frames before declaring object as permanently lost

tracker_config = 'bytetrack.yaml'

# Initialize video capture to get frame for ROI selection
cap = cv2.VideoCapture(video_path)
ret, first_frame = cap.read()
if not ret:
    raise RuntimeError("Could not read first frame")

# Apply Canny edge detection using Sobel filter
first_frame_gray = cv2.cvtColor(first_frame, cv2.COLOR_BGR2GRAY)
grad_x = cv2.Sobel(first_frame_gray, cv2.CV_16S, 1, 0, ksize=3)
grad_y = cv2.Sobel(first_frame_gray, cv2.CV_16S, 0, 1, ksize=3)
grad_x = cv2.convertScaleAbs(grad_x)
grad_y = cv2.convertScaleAbs(grad_y)
combined_gradient = cv2.addWeighted(grad_x, 0.5, grad_y, 0.5, 0)
edges = cv2.Canny(combined_gradient, 100, 200)
first_frame_edges = cv2.cvtColor(edges, cv2.COLOR_GRAY2BGR)

# Overlay the edges onto the original frame for visualization
first_frame_overlay = cv2.addWeighted(first_frame, 0.8, first_frame_edges, 0.2, 0)

# Get ROI from user
print("Select ROI and press ENTER. Press C to cancel.")
roi = cv2.selectROI("Select ROI", first_frame_overlay, fromCenter=False, showCrosshair=True)
cv2.destroyWindow("Select ROI")
x_min, y_min, w, h = roi
x_max, y_max = x_min + w, y_min + h

# Get video properties
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
cap.release()

# Load YOLO model
model = YOLO(model_path)

# Initialize the tracking generator
generator = model.track(
    source=video_path,
    imgsz=960,
    conf=detection_conf_thresh,
    iou=detection_nms_thresh,
    tracker=tracker_config,
    stream=True
)

# Prepare video writer
output_video_path = os.path.join(save_dir, "sobel_filter.mp4")
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out_writer = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

# State management
active_objects = []      # List of (label, box) tuples for current objects
lost_objects = {}        # Dict of label: (box, last_seen_frame) for lost objects
next_label_num = 1      # Counter for generating unique object labels
objects_that_left = set()  # Set of labels for objects that have left the scene
frame_count = 0
box_color = (0, 255, 0)

# Main processing loop
while True:
    try:
        results = next(generator)
    except StopIteration:
        break

    frame_count += 1
    frame = results.orig_img.copy()

    # Apply Canny edge detection using Sobel filter
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    grad_x = cv2.Sobel(gray, cv2.CV_16S, 1, 0, ksize=3)
    grad_y = cv2.Sobel(gray, cv2.CV_16S, 0, 1, ksize=3)
    grad_x = cv2.convertScaleAbs(grad_x)
    grad_y = cv2.convertScaleAbs(grad_y)
    combined_gradient = cv2.addWeighted(grad_x, 0.5, grad_y, 0.5, 0)
    edges = cv2.Canny(combined_gradient, 100, 200)
    edges_colored = cv2.cvtColor(edges, cv2.COLOR_GRAY2BGR)

    # Overlay the edges onto the original frame
    frame = cv2.addWeighted(frame, 0.8, edges_colored, 0.2, 0)

    # Filter boxes to only include those within ROI
    boxes = []
    for b in results.boxes:
        x1, y1, x2, y2 = map(int, b.xyxy[0])
        if (x_min <= x1 <= x_max and x_min <= x2 <= x_max and
            y_min <= y1 <= y_max and y_min <= y2 <= y_max):
            boxes.append((x1, y1, x2, y2))

    if boxes:
        # Group boxes into shelves
        boxes.sort(key=lambda b: b[3])
        shelves = []
        for bx in boxes:
            x1, y1, x2, y2 = bx
            placed = False
            for shelf in shelves:
                shelf_bottoms = [b[3] for b in shelf]
                shelf_mean_bottom = sum(shelf_bottoms) / len(shelf_bottoms)
                if abs(y2 - shelf_mean_bottom) <= shelf_thresh:
                    shelf.append(bx)
                    placed = True
                    break
            if not placed:
                shelves.append([bx])

        # Sort shelves and create final box list
        for shelf in shelves:
            shelf.sort(key=lambda b: b[0])
        sorted_boxes = [b for shelf in shelves for b in shelf]

        # Track objects
        new_objects = []
        used_active_labels = set()

        for new_box in sorted_boxes:
            # Try to match with active objects
            best_iou = 0
            best_label = None
            for (lbl, a_box) in active_objects:
                iou_val = iou(a_box, new_box)
                if iou_val > best_iou:
                    best_iou = iou_val
                    best_label = lbl

            if best_iou > tracking_iou_thresh:
                new_objects.append((best_label, new_box))
                used_active_labels.add(best_label)
            else:
                # Try to match with lost objects
                best_iou_lost = 0
                best_lost_label = None
                for lbl, (l_box, l_frame) in lost_objects.items():
                    if frame_count - l_frame <= lost_time_limit:
                        iou_val = iou(l_box, new_box)
                        if iou_val > best_iou_lost:
                            best_iou_lost = iou_val
                            best_lost_label = lbl

                if best_iou_lost > tracking_iou_thresh and best_lost_label is not None:
                    new_objects.append((best_lost_label, new_box))
                    used_active_labels.add(best_lost_label)
                    del lost_objects[best_lost_label]
                    objects_that_left.discard(best_lost_label)
                else:
                    new_objects.append((next_label_num, new_box))
                    used_active_labels.add(next_label_num)
                    next_label_num += 1

        # Handle disappeared objects
        active_labels = {lbl for (lbl, _) in active_objects}
        disappeared = active_labels - used_active_labels
        for lbl in disappeared:
            for (l, box) in active_objects:
                if l == lbl:
                    lost_objects[lbl] = (box, frame_count)
                    objects_that_left.add(lbl)

        # Clean up lost objects
        lost_objects = {
            lbl: (box, frame) 
            for lbl, (box, frame) in lost_objects.items() 
            if frame_count - frame <= lost_time_limit
        }

        active_objects = new_objects

        # Draw visualizations
        # Draw ROI
        cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), (255, 0, 0), 2)

        # Draw bounding boxes and labels
        for (lbl, (x1, y1, x2, y2)) in active_objects:
            cv2.rectangle(frame, (x1, y1), (x2, y2), box_color, 2)
            cv2.putText(frame, f"{lbl}", (x1 + 5, y1 + 20), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.7, box_color, 2)

        # Draw shelf boundaries
        for idx, shelf in enumerate(shelves, start=1):
            y = min(b[3] for b in shelf)
            cv2.line(frame, (0, y), (width, y), (0, 0, 255), 2)
            cv2.putText(frame, f"Shelf {idx}", (10, y - 10), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

        # Draw status information
        if objects_that_left:
            text = f"Objects that have left: {', '.join(map(str, objects_that_left))}"
            cv2.putText(frame, text, (100, 90), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)

        cv2.putText(frame, f"Total objects in scene: {len(active_objects)}", 
                   (100, 45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    else:
        # Handle case when no boxes are detected
        for (lbl, box) in active_objects:
            lost_objects[lbl] = (box, frame_count)
            objects_that_left.add(lbl)
        active_objects = []

    out_writer.write(frame)

out_writer.release()
print(f"Processed video saved to {output_video_path}")

# Automatically play the processed video
def play_video(video_path):
    cap = cv2.VideoCapture(video_path)
    
    # Get video properties
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    frame_delay = int(1000/fps)  # Convert fps to milliseconds delay between frames
    
    while True:
        ret, frame = cap.read()
        if not ret:
            break
            
        cv2.imshow('Processed Video', frame)
        
        # Break loop if 'q' is pressed or window is closed
        key = cv2.waitKey(frame_delay) & 0xFF
        if key == ord('q') or cv2.getWindowProperty('Processed Video', cv2.WND_PROP_VISIBLE) < 1:
            break
    
    cap.release()
    cv2.destroyAllWindows()

# Play the processed video
print("Playing processed video (press 'q' to quit)...")
play_video(output_video_path)
# Out:
# Select ROI and press ENTER. Press C to cancel.
#
# video 1/1 (frame 1/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 30 obs, 43.9ms
# video 1/1 (frame 2/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 30 obs, 9.1ms
# video 1/1 (frame 3/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 30 obs, 9.1ms
# video 1/1 (frame 4/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 30 obs, 9.5ms
# video 1/1 (frame 5/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 30 obs, 9.0ms
# video 1/1 (frame 6/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 30 obs, 8.5ms
# video 1/1 (frame 7/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 30 obs, 7.4ms
# video 1/1 (frame 8/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 30 obs, 8.7ms
# video 1/1 (frame 9/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 30 obs, 8.2ms
# video 1/1 (frame 10/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 30 obs, 7.7ms
# video 1/1 (frame 11/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 30 obs, 9.7ms
# video 1/1 (frame 12/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 30 obs, 9.1ms
# video 1/1 (frame 13/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 30 obs, 8.0ms
# video 1/1 (frame 14/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 30 obs, 8.7ms
# video 1/1 (frame 15/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 30 obs, 9.5ms
# video 1/1 (frame 16/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 30 obs, 8.2ms
# video 1/1 (frame 17/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 30 obs, 10.6ms
# video 1/1 (frame 18/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 30 obs, 10.0ms
# video 1/1 (frame 19/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 30 obs, 8.2ms
# video 1/1 (frame 20/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 30 obs, 8.2ms
# video 1/1 (frame 21/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 8.5ms
# video 1/1 (frame 22/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 7.0ms
# video 1/1 (frame 23/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 8.5ms
# video 1/1 (frame 24/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 9.0ms
# video 1/1 (frame 25/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 7.3ms
# video 1/1 (frame 26/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 8.5ms
# video 1/1 (frame 27/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 9.0ms
# video 1/1 (frame 28/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 8.2ms
# video 1/1 (frame 29/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 8.0ms
# video 1/1 (frame 30/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 8.0ms
# video 1/1 (frame 31/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 9.6ms
# video 1/1 (frame 32/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 7.5ms
# video 1/1 (frame 33/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 8.0ms
# video 1/1 (frame 34/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 8.1ms
# video 1/1 (frame 35/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 8.5ms
# video 1/1 (frame 36/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 7.7ms
# video 1/1 (frame 37/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 7.5ms
# video 1/1 (frame 38/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 10.9ms
# video 1/1 (frame 39/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 9.4ms
# video 1/1 (frame 40/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 10.2ms
# video 1/1 (frame 41/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 9.1ms
# video 1/1 (frame 42/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 8.7ms
# video 1/1 (frame 43/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 7.8ms
# video 1/1 (frame 44/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 8.0ms
# video 1/1 (frame 45/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 10.5ms
# video 1/1 (frame 46/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 8.0ms
# video 1/1 (frame 47/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 9.5ms
# video 1/1 (frame 48/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 9.5ms
# video 1/1 (frame 49/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 10.0ms
# video 1/1 (frame 50/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 8.6ms
# video 1/1 (frame 51/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 7.7ms
# video 1/1 (frame 52/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 8.2ms
# video 1/1 (frame 53/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 8.6ms
# video 1/1 (frame 54/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 8.5ms
# video 1/1 (frame 55/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 29 obs, 8.0ms
# video 1/1 (frame 56/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 7.5ms
# video 1/1 (frame 57/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 8.5ms
# video 1/1 (frame 58/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 8.1ms
# video 1/1 (frame 59/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 8.5ms
# video 1/1 (frame 60/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 8.5ms
# video 1/1 (frame 61/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 7.6ms
# video 1/1 (frame 62/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 9.2ms
# video 1/1 (frame 63/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 29 obs, 7.5ms
# video 1/1 (frame 64/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 29 obs, 8.0ms
# video 1/1 (frame 65/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 28 obs, 7.9ms
# video 1/1 (frame 66/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 29 obs, 8.5ms
# video 1/1 (frame 67/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 29 obs, 17.7ms
# video 1/1 (frame 68/68) C:\Users\joshu\Downloads\before and after vid.mp4: 544x960 29 obs, 8.7ms
# Speed: 2.6ms preprocess, 9.2ms inference, 2.2ms postprocess per image at shape (1, 3, 544, 960)
# Processed video saved to C:\Users\joshu\Documents\EEE\AMNIS\output_videos\sobel_filter.mp4
# Playing processed video (press 'q' to quit)...

# %%
#trying some image pre processing


from ultralytics import YOLO
import cv2
import os
import time
import numpy as np

def iou(boxA, boxB):
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])
    interArea = max(0, xB - xA) * max(0, yB - yA)  # Area of intersection
    boxAArea = (boxA[2] - boxA[0]) * (boxA[3] - boxA[1])  # Area of boxA
    boxBArea = (boxB[2] - boxB[0]) * (boxB[3] - boxB[1])  # Area of boxB
    if boxAArea == 0 or boxBArea == 0:
        return 0.0
    return interArea / float(boxAArea + boxBArea - interArea)

# ------------------------------------------------------------
# Configuration
# ------------------------------------------------------------
model_path = r"C:\Users\joshu\Documents\EEE\AMNIS\Models\training\weights\best.pt"
video_path = r"C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4"
save_dir = r"C:\Users\joshu\Documents\EEE\AMNIS\output_videos"
os.makedirs(save_dir, exist_ok=True)

# Detection thresholds
detection_conf_thresh = 0.02   # Confidence threshold for YOLO detections
detection_nms_thresh = 0.5     # NMS IOU threshold for YOLO detections

# Tracking thresholds
tracking_iou_thresh = 0.5      # IOU threshold for object tracking/matching
shelf_thresh = 100            # Vertical distance threshold for shelf grouping
lost_time_limit = 300         # Frames before declaring object as permanently lost

tracker_config = 'bytetrack.yaml'

# Initialize video capture to get frame for ROI selection
cap = cv2.VideoCapture(video_path)
ret, first_frame = cap.read()
if not ret:
    raise RuntimeError("Could not read first frame")

# Get ROI from user
print("Select ROI and press ENTER. Press C to cancel.")
roi = cv2.selectROI("Select ROI", first_frame, fromCenter=False, showCrosshair=True)
cv2.destroyWindow("Select ROI")
x_min, y_min, w, h = roi
x_max, y_max = x_min + w, y_min + h

# Get video properties
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
cap.release()

# Load YOLO model
model = YOLO(model_path)

# Initialize the tracking generator
generator = model.track(
    source=video_path,
    imgsz=640,
    conf=detection_conf_thresh,
    iou=detection_nms_thresh,
    tracker=tracker_config,
    stream=True
)

# Prepare video writer
output_video_path = os.path.join(save_dir, "tracked_with_roi.mp4")
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out_writer = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

# State management
active_objects = []      # List of (label, box) tuples for current objects
lost_objects = {}        # Dict of label: (box, last_seen_frame) for lost objects
next_label_num = 1      # Counter for generating unique object labels
objects_that_left = set()  # Set of labels for objects that have left the scene
frame_count = 0
box_color = (0, 255, 0)

# Main processing loop
while True:
    try:
        results = next(generator)
    except StopIteration:
        break

    frame_count += 1
    frame = results.orig_img.copy()

    # Enhance contrast and edges within the ROI
    roi_frame = frame[y_min:y_max, x_min:x_max]

    # Apply contrast enhancement (CLAHE)
    lab = cv2.cvtColor(roi_frame, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    l = clahe.apply(l)
    enhanced_lab = cv2.merge((l, a, b))
    roi_frame = cv2.cvtColor(enhanced_lab, cv2.COLOR_LAB2BGR)

    # Apply edge detection
    edges = cv2.Canny(roi_frame, 100, 200)
    edges_colored = cv2.cvtColor(edges, cv2.COLOR_GRAY2BGR)
    roi_frame = cv2.addWeighted(roi_frame, 0.8, edges_colored, 0.2, 0)

    # Replace the ROI in the original frame
    frame[y_min:y_max, x_min:x_max] = roi_frame

    # Filter boxes to only include those within ROI
    boxes = []
    for b in results.boxes:
        x1, y1, x2, y2 = map(int, b.xyxy[0])
        if (x_min <= x1 <= x_max and x_min <= x2 <= x_max and
            y_min <= y1 <= y_max and y_min <= y2 <= y_max):
            boxes.append((x1, y1, x2, y2))

    if boxes:
        # Group boxes into shelves
        boxes.sort(key=lambda b: b[3])
        shelves = []
        for bx in boxes:
            x1, y1, x2, y2 = bx
            placed = False
            for shelf in shelves:
                shelf_bottoms = [b[3] for b in shelf]
                shelf_mean_bottom = sum(shelf_bottoms) / len(shelf_bottoms)
                if abs(y2 - shelf_mean_bottom) <= shelf_thresh:
                    shelf.append(bx)
                    placed = True
                    break
            if not placed:
                shelves.append([bx])

        # Sort shelves and create final box list
        for shelf in shelves:
            shelf.sort(key=lambda b: b[0])
        sorted_boxes = [b for shelf in shelves for b in shelf]

        # Track objects
        new_objects = []
        used_active_labels = set()

        for new_box in sorted_boxes:
            # Try to match with active objects
            best_iou = 0
            best_label = None
            for (lbl, a_box) in active_objects:
                iou_val = iou(a_box, new_box)
                if iou_val > best_iou:
                    best_iou = iou_val
                    best_label = lbl

            if best_iou > tracking_iou_thresh:
                new_objects.append((best_label, new_box))
                used_active_labels.add(best_label)
            else:
                # Try to match with lost objects
                best_iou_lost = 0
                best_lost_label = None
                for lbl, (l_box, l_frame) in lost_objects.items():
                    if frame_count - l_frame <= lost_time_limit:
                        iou_val = iou(l_box, new_box)
                        if iou_val > best_iou_lost:
                            best_iou_lost = iou_val
                            best_lost_label = lbl

                if best_iou_lost > tracking_iou_thresh and best_lost_label is not None:
                    new_objects.append((best_lost_label, new_box))
                    used_active_labels.add(best_lost_label)
                    del lost_objects[best_lost_label]
                    objects_that_left.discard(best_lost_label)
                else:
                    new_objects.append((next_label_num, new_box))
                    used_active_labels.add(next_label_num)
                    next_label_num += 1

        # Handle disappeared objects
        active_labels = {lbl for (lbl, _) in active_objects}
        disappeared = active_labels - used_active_labels
        for lbl in disappeared:
            for (l, box) in active_objects:
                if l == lbl:
                    lost_objects[lbl] = (box, frame_count)
                    objects_that_left.add(lbl)

        # Clean up lost objects
        lost_objects = {
            lbl: (box, frame) 
            for lbl, (box, frame) in lost_objects.items() 
            if frame_count - frame <= lost_time_limit
        }

        active_objects = new_objects

        # Draw visualizations
        # Draw ROI
        cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), (255, 0, 0), 2)

        # Draw bounding boxes and labels
        for (lbl, (x1, y1, x2, y2)) in active_objects:
            cv2.rectangle(frame, (x1, y1), (x2, y2), box_color, 2)
            cv2.putText(frame, f"{lbl}", (x1 + 5, y1 + 20), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.7, box_color, 2)

        # Draw shelf boundaries
        for idx, shelf in enumerate(shelves, start=1):
            y = min(b[3] for b in shelf)
            cv2.line(frame, (0, y), (width, y), (0, 0, 255), 2)
            cv2.putText(frame, f"Shelf {idx}", (10, y - 10), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

        # Draw status information
        if objects_that_left:
            text = f"Objects that have left: {', '.join(map(str, objects_that_left))}"
            cv2.putText(frame, text, (100, 90), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)

        cv2.putText(frame, f"Total objects in scene: {len(active_objects)}", 
                   (100, 45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    else:
        # Handle case when no boxes are detected
        for (lbl, box) in active_objects:
            lost_objects[lbl] = (box, frame_count)
            objects_that_left.add(lbl)
        active_objects = []

    out_writer.write(frame)

out_writer.release()
print(f"Processed video saved to {output_video_path}")

# Automatically play the processed video
def play_video(video_path):
    cap = cv2.VideoCapture(video_path)
    
    # Get video properties
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    frame_delay = int(1000/fps)  # Convert fps to milliseconds delay between frames
    
    while True:
        ret, frame = cap.read()
        if not ret:
            break
            
        cv2.imshow('Processed Video', frame)
        
        # Break loop if 'q' is pressed or window is closed
        key = cv2.waitKey(frame_delay) & 0xFF
        if key == ord('q') or cv2.getWindowProperty('Processed Video', cv2.WND_PROP_VISIBLE) < 1:
            break
    
    cap.release()
    cv2.destroyAllWindows()

# Play the processed video
print("Playing processed video (press 'q' to quit)...")
play_video(output_video_path)
# Out:
# Select ROI and press ENTER. Press C to cancel.
#
# video 1/1 (frame 1/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 51.9ms
# video 1/1 (frame 2/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 8.2ms
# video 1/1 (frame 3/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 8.5ms
# video 1/1 (frame 4/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 7.7ms
# video 1/1 (frame 5/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 8.5ms
# video 1/1 (frame 6/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 8.3ms
# video 1/1 (frame 7/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 8.0ms
# video 1/1 (frame 8/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 8.3ms
# video 1/1 (frame 9/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 8.0ms
# video 1/1 (frame 10/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 9.7ms
# video 1/1 (frame 11/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 8.3ms
# video 1/1 (frame 12/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 9.1ms
# video 1/1 (frame 13/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 9.0ms
# video 1/1 (frame 14/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 8.5ms
# video 1/1 (frame 15/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 9.0ms
# video 1/1 (frame 16/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 7.8ms
# video 1/1 (frame 17/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 7.6ms
# video 1/1 (frame 18/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 19 obs, 8.0ms
# video 1/1 (frame 19/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 17.1ms
# video 1/1 (frame 20/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 7.5ms
# video 1/1 (frame 21/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 8.5ms
# video 1/1 (frame 22/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 7.7ms
# video 1/1 (frame 23/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 8.0ms
# video 1/1 (frame 24/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 8.5ms
# video 1/1 (frame 25/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 9.0ms
# video 1/1 (frame 26/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 8.1ms
# video 1/1 (frame 27/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 7.1ms
# video 1/1 (frame 28/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 10.0ms
# video 1/1 (frame 29/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 7.9ms
# video 1/1 (frame 30/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 8.1ms
# video 1/1 (frame 31/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 21 obs, 9.5ms
# video 1/1 (frame 32/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 21 obs, 9.5ms
# video 1/1 (frame 33/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 21 obs, 10.0ms
# video 1/1 (frame 34/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 21 obs, 8.5ms
# video 1/1 (frame 35/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 21 obs, 8.4ms
# video 1/1 (frame 36/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 21 obs, 8.9ms
# video 1/1 (frame 37/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 20 obs, 8.5ms
# video 1/1 (frame 38/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 21 obs, 7.0ms
# video 1/1 (frame 39/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 8.0ms
# video 1/1 (frame 40/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.0ms
# video 1/1 (frame 41/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 8.4ms
# video 1/1 (frame 42/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 18.7ms
# video 1/1 (frame 43/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.2ms
# video 1/1 (frame 44/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.1ms
# video 1/1 (frame 45/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 7.9ms
# video 1/1 (frame 46/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 8.1ms
# video 1/1 (frame 47/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 8.4ms
# video 1/1 (frame 48/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 7.7ms
# video 1/1 (frame 49/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 9.0ms
# video 1/1 (frame 50/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 21 obs, 8.0ms
# video 1/1 (frame 51/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 7.6ms
# video 1/1 (frame 52/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 21 obs, 8.7ms
# video 1/1 (frame 53/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 8.4ms
# video 1/1 (frame 54/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 7.5ms
# video 1/1 (frame 55/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 8.5ms
# video 1/1 (frame 56/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 7.6ms
# video 1/1 (frame 57/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 8.1ms
# video 1/1 (frame 58/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 8.1ms
# video 1/1 (frame 59/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 8.6ms
# video 1/1 (frame 60/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 9.0ms
# video 1/1 (frame 61/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 8.7ms
# video 1/1 (frame 62/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 8.0ms
# video 1/1 (frame 63/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 7.5ms
# video 1/1 (frame 64/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 8.5ms
# video 1/1 (frame 65/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 18.4ms
# video 1/1 (frame 66/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 7.1ms
# video 1/1 (frame 67/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 8.6ms
# video 1/1 (frame 68/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 8.6ms
# video 1/1 (frame 69/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 8.5ms
# video 1/1 (frame 70/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 8.1ms
# video 1/1 (frame 71/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 7.3ms
# video 1/1 (frame 72/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 8.7ms
# video 1/1 (frame 73/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 7.5ms
# video 1/1 (frame 74/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 7.2ms
# video 1/1 (frame 75/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 7.5ms
# video 1/1 (frame 76/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 7.1ms
# video 1/1 (frame 77/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 7.8ms
# video 1/1 (frame 78/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 8.2ms
# video 1/1 (frame 79/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 8.1ms
# video 1/1 (frame 80/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 9.0ms
# video 1/1 (frame 81/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.5ms
# video 1/1 (frame 82/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.0ms
# video 1/1 (frame 83/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 7.7ms
# video 1/1 (frame 84/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.0ms
# video 1/1 (frame 85/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 7.3ms
# video 1/1 (frame 86/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.0ms
# video 1/1 (frame 87/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.1ms
# video 1/1 (frame 88/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 7.5ms
# video 1/1 (frame 89/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.5ms
# video 1/1 (frame 90/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.0ms
# video 1/1 (frame 91/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 7.5ms
# video 1/1 (frame 92/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 16.0ms
# video 1/1 (frame 93/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.7ms
# video 1/1 (frame 94/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.0ms
# video 1/1 (frame 95/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 7.5ms
# video 1/1 (frame 96/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.3ms
# video 1/1 (frame 97/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.5ms
# video 1/1 (frame 98/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.5ms
# video 1/1 (frame 99/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.1ms
# video 1/1 (frame 100/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.0ms
# video 1/1 (frame 101/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.0ms
# video 1/1 (frame 102/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 7.7ms
# video 1/1 (frame 103/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 7.5ms
# video 1/1 (frame 104/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.3ms
# video 1/1 (frame 105/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.1ms
# video 1/1 (frame 106/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.5ms
# video 1/1 (frame 107/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 7.2ms
# video 1/1 (frame 108/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 7.7ms
# video 1/1 (frame 109/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.1ms
# video 1/1 (frame 110/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 12.0ms
# video 1/1 (frame 111/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.7ms
# video 1/1 (frame 112/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 7.5ms
# video 1/1 (frame 113/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.0ms
# video 1/1 (frame 114/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 7.0ms
# video 1/1 (frame 115/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.0ms
# video 1/1 (frame 116/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.0ms
# video 1/1 (frame 117/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.2ms
# video 1/1 (frame 118/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 7.0ms
# video 1/1 (frame 119/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 7.7ms
# video 1/1 (frame 120/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.0ms
# video 1/1 (frame 121/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.2ms
# video 1/1 (frame 122/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 7.5ms
# video 1/1 (frame 123/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 7.5ms
# video 1/1 (frame 124/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.0ms
# video 1/1 (frame 125/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.1ms
# video 1/1 (frame 126/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.0ms
# video 1/1 (frame 127/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.0ms
# video 1/1 (frame 128/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.4ms
# video 1/1 (frame 129/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 7.5ms
# video 1/1 (frame 130/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.0ms
# video 1/1 (frame 131/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.0ms
# video 1/1 (frame 132/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.0ms
# video 1/1 (frame 133/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 10.5ms
# video 1/1 (frame 134/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.2ms
# video 1/1 (frame 135/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.5ms
# video 1/1 (frame 136/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.2ms
# video 1/1 (frame 137/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.0ms
# video 1/1 (frame 138/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.0ms
# video 1/1 (frame 139/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.5ms
# video 1/1 (frame 140/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 8.6ms
# video 1/1 (frame 141/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.5ms
# video 1/1 (frame 142/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 8.2ms
# video 1/1 (frame 143/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.0ms
# video 1/1 (frame 144/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.1ms
# video 1/1 (frame 145/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 8.5ms
# video 1/1 (frame 146/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 8.2ms
# video 1/1 (frame 147/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 8.7ms
# video 1/1 (frame 148/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.2ms
# video 1/1 (frame 149/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.0ms
# video 1/1 (frame 150/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 9.0ms
# video 1/1 (frame 151/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 8.5ms
# video 1/1 (frame 152/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 8.7ms
# video 1/1 (frame 153/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 8.5ms
# video 1/1 (frame 154/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 9.5ms
# video 1/1 (frame 155/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 8.6ms
# video 1/1 (frame 156/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 8.8ms
# video 1/1 (frame 157/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 8.5ms
# video 1/1 (frame 158/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 8.6ms
# video 1/1 (frame 159/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 10.7ms
# video 1/1 (frame 160/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 8.6ms
# video 1/1 (frame 161/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 9.4ms
# video 1/1 (frame 162/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 9.8ms
# video 1/1 (frame 163/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 9.0ms
# video 1/1 (frame 164/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 9.0ms
# video 1/1 (frame 165/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 10.1ms
# video 1/1 (frame 166/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 9.0ms
# video 1/1 (frame 167/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 10.2ms
# video 1/1 (frame 168/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 8.7ms
# video 1/1 (frame 169/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 8.9ms
# video 1/1 (frame 170/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 8.5ms
# video 1/1 (frame 171/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 10.0ms
# video 1/1 (frame 172/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 10.0ms
# video 1/1 (frame 173/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 9.5ms
# video 1/1 (frame 174/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 8.7ms
# video 1/1 (frame 175/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 9.0ms
# video 1/1 (frame 176/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 10.0ms
# video 1/1 (frame 177/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 8.1ms
# video 1/1 (frame 178/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 9.5ms
# video 1/1 (frame 179/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.2ms
# video 1/1 (frame 180/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.5ms
# video 1/1 (frame 181/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.0ms
# video 1/1 (frame 182/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.7ms
# video 1/1 (frame 183/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.5ms
# video 1/1 (frame 184/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.6ms
# video 1/1 (frame 185/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.7ms
# video 1/1 (frame 186/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 8.5ms
# video 1/1 (frame 187/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 9.7ms
# video 1/1 (frame 188/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.5ms
# video 1/1 (frame 189/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 10.0ms
# video 1/1 (frame 190/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 9.0ms
# video 1/1 (frame 191/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 8.5ms
# video 1/1 (frame 192/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 15.0ms
# video 1/1 (frame 193/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 10.0ms
# video 1/1 (frame 194/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 9.9ms
# video 1/1 (frame 195/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 9.6ms
# video 1/1 (frame 196/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 9.5ms
# video 1/1 (frame 197/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 15.0ms
# video 1/1 (frame 198/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 9.5ms
# video 1/1 (frame 199/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 11.0ms
# video 1/1 (frame 200/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 10.1ms
# video 1/1 (frame 201/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 9.5ms
# video 1/1 (frame 202/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 10.0ms
# video 1/1 (frame 203/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 9.5ms
# video 1/1 (frame 204/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 10.0ms
# video 1/1 (frame 205/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 10.0ms
# video 1/1 (frame 206/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 9.5ms
# video 1/1 (frame 207/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.7ms
# video 1/1 (frame 208/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.0ms
# video 1/1 (frame 209/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.4ms
# video 1/1 (frame 210/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.1ms
# video 1/1 (frame 211/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 10.0ms
# video 1/1 (frame 212/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 10.5ms
# video 1/1 (frame 213/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 10.0ms
# video 1/1 (frame 214/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 9.8ms
# video 1/1 (frame 215/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 10.7ms
# video 1/1 (frame 216/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 10.0ms
# video 1/1 (frame 217/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.7ms
# video 1/1 (frame 218/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.5ms
# video 1/1 (frame 219/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.5ms
# video 1/1 (frame 220/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.2ms
# video 1/1 (frame 221/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.5ms
# video 1/1 (frame 222/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.7ms
# video 1/1 (frame 223/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.0ms
# video 1/1 (frame 224/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.2ms
# video 1/1 (frame 225/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.6ms
# video 1/1 (frame 226/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.6ms
# video 1/1 (frame 227/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.5ms
# video 1/1 (frame 228/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 11.0ms
# video 1/1 (frame 229/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 10.0ms
# video 1/1 (frame 230/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 10.3ms
# video 1/1 (frame 231/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 11.4ms
# video 1/1 (frame 232/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 11.0ms
# video 1/1 (frame 233/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 10.7ms
# video 1/1 (frame 234/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 10.0ms
# video 1/1 (frame 235/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.0ms
# video 1/1 (frame 236/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.5ms
# video 1/1 (frame 237/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.4ms
# video 1/1 (frame 238/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.1ms
# video 1/1 (frame 239/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.3ms
# video 1/1 (frame 240/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.0ms
# video 1/1 (frame 241/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.4ms
# video 1/1 (frame 242/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.5ms
# video 1/1 (frame 243/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.5ms
# video 1/1 (frame 244/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.5ms
# video 1/1 (frame 245/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.5ms
# video 1/1 (frame 246/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.1ms
# video 1/1 (frame 247/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 22 obs, 10.6ms
# video 1/1 (frame 248/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.0ms
# video 1/1 (frame 249/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.0ms
# video 1/1 (frame 250/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.0ms
# video 1/1 (frame 251/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.0ms
# video 1/1 (frame 252/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.5ms
# video 1/1 (frame 253/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.4ms
# video 1/1 (frame 254/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.5ms
# video 1/1 (frame 255/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.0ms
# video 1/1 (frame 256/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.0ms
# video 1/1 (frame 257/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.0ms
# video 1/1 (frame 258/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.5ms
# video 1/1 (frame 259/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.6ms
# video 1/1 (frame 260/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.0ms
# video 1/1 (frame 261/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.0ms
# video 1/1 (frame 262/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 15.0ms
# video 1/1 (frame 263/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.1ms
# video 1/1 (frame 264/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.6ms
# video 1/1 (frame 265/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.0ms
# video 1/1 (frame 266/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 12.0ms
# video 1/1 (frame 267/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.5ms
# video 1/1 (frame 268/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.5ms
# video 1/1 (frame 269/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.4ms
# video 1/1 (frame 270/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 9.9ms
# video 1/1 (frame 271/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.0ms
# video 1/1 (frame 272/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.0ms
# video 1/1 (frame 273/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.1ms
# video 1/1 (frame 274/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.1ms
# video 1/1 (frame 275/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.5ms
# video 1/1 (frame 276/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.0ms
# video 1/1 (frame 277/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 14.1ms
# video 1/1 (frame 278/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.0ms
# video 1/1 (frame 279/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.4ms
# video 1/1 (frame 280/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.1ms
# video 1/1 (frame 281/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 12.0ms
# video 1/1 (frame 282/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.1ms
# video 1/1 (frame 283/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.0ms
# video 1/1 (frame 284/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.6ms
# video 1/1 (frame 285/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 12.1ms
# video 1/1 (frame 286/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 10.8ms
# video 1/1 (frame 287/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.2ms
# video 1/1 (frame 288/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 23 obs, 11.2ms
# video 1/1 (frame 289/289) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241204_jp\20241204_102758_0.mp4: 384x640 24 obs, 11.1ms
# Speed: 1.0ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed video saved to C:\Users\joshu\Documents\EEE\AMNIS\output_videos\tracked_with_roi.mp4
# Playing processed video (press 'q' to quit)...

# %%
#heatmap testing

from ultralytics import YOLO
import cv2
import os
import time
import numpy as np

def iou(boxA, boxB):
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])
    interArea = max(0, xB - xA) * max(0, yB - yA)  # Area of intersection
    boxAArea = (boxA[2] - boxA[0]) * (boxA[3] - boxA[1])  # Area of boxA
    boxBArea = (boxB[2] - boxB[0]) * (boxB[3] - boxB[1])  # Area of boxB
    if boxAArea == 0 or boxBArea == 0:
        return 0.0
    return interArea / float(boxAArea + boxBArea - interArea)

# ------------------------------------------------------------
# Configuration
# ------------------------------------------------------------
model_path = r"C:\Users\joshu\Documents\EEE\AMNIS\Models\training\weights\best.pt"
video_path = r"C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4"
save_dir = r"C:\Users\joshu\Documents\EEE\AMNIS\output_videos"
os.makedirs(save_dir, exist_ok=True)

# Detection thresholds
detection_conf_thresh = 0.1   # Confidence threshold for YOLO detections
detection_nms_thresh = 0.01   # NMS IOU threshold for YOLO detections

# Tracking thresholds
tracking_iou_thresh = 0.9  # IOU threshold for object tracking/matching
shelf_thresh = 100            # Vertical distance threshold for shelf grouping
lost_time_limit = 300         # Frames before declaring object as permanently lost

tracker_config = 'bytetrack.yaml'

# Initialize video capture to get frame for ROI selection
cap = cv2.VideoCapture(video_path)
ret, first_frame = cap.read()
if not ret:
    raise RuntimeError("Could not read first frame")

# Get ROI from user
print("Select ROI and press ENTER. Press C to cancel.")
roi = cv2.selectROI("Select ROI", first_frame, fromCenter=False, showCrosshair=True)
cv2.destroyWindow("Select ROI")
x_min, y_min, w, h = roi
x_max, y_max = x_min + w, y_min + h

# Get video properties
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
cap.release()

# Load YOLO model
model = YOLO(model_path)

# Initialize the tracking generator
generator = model.track(
    source=video_path,
    imgsz=640,
    conf=detection_conf_thresh,
    iou=detection_nms_thresh,
    tracker=tracker_config,
    stream=True
)

# Prepare video writer
output_video_path = os.path.join(save_dir, "heatmap.mp4")
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out_writer = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

# State management
active_objects = []      # List of (label, box) tuples for current objects
lost_objects = {}        # Dict of label: (box, last_seen_frame) for lost objects
next_label_num = 1      # Counter for generating unique object labels
objects_that_left = set()  # Set of labels for objects that have left the scene
frame_count = 0
box_color = (0, 255, 0)

# Function to create a Gaussian heatmap
def create_gaussian_heatmap(roi_shape, boxes):
    heatmap = np.zeros(roi_shape[:2], dtype=np.float32)
    for x1, y1, x2, y2 in boxes:
        cx, cy = (x1 + x2) // 2, (y1 + y2) // 2
        sigma_x = max(1, (x2 - x1) // 2)
        sigma_y = max(1, (y2 - y1) // 2)
        for x in range(x1, x2):
            for y in range(y1, y2):
                heatmap[y, x] += np.exp(-(((x - cx) ** 2) / (2 * sigma_x ** 2) + ((y - cy) ** 2) / (2 * sigma_y ** 2)))
    heatmap = cv2.normalize(heatmap, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
    return heatmap

# Main processing loop
while True:
    try:
        results = next(generator)
    except StopIteration:
        break

    frame_count += 1
    frame = results.orig_img.copy()

    # Extract ROI frame
    roi_frame = frame[y_min:y_max, x_min:x_max]

    # Filter boxes to only include those within ROI
    boxes = []
    for b in results.boxes:
        x1, y1, x2, y2 = map(int, b.xyxy[0])
        if (x_min <= x1 <= x_max and x_min <= x2 <= x_max and
            y_min <= y1 <= y_max and y_min <= y2 <= y_max):
            boxes.append((x1 - x_min, y1 - y_min, x2 - x_min, y2 - y_min))

    if boxes:
        # Create Gaussian heatmap
        heatmap = create_gaussian_heatmap(roi_frame.shape, boxes)
        heatmap_colored = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
        roi_frame = cv2.addWeighted(roi_frame, 0.7, heatmap_colored, 0.3, 0)

    # Replace the ROI in the original frame
    frame[y_min:y_max, x_min:x_max] = roi_frame

    # Write frame to video
    out_writer.write(frame)

out_writer.release()
print(f"Processed video saved to {output_video_path}")

# Automatically play the processed video
def play_video(video_path):
    cap = cv2.VideoCapture(video_path)
    
    # Get video properties
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    frame_delay = int(1000/fps)  # Convert fps to milliseconds delay between frames
    
    while True:
        ret, frame = cap.read()
        if not ret:
            break
            
        cv2.imshow('Processed Video', frame)
        
        # Break loop if 'q' is pressed or window is closed
        key = cv2.waitKey(frame_delay) & 0xFF
        if key == ord('q') or cv2.getWindowProperty('Processed Video', cv2.WND_PROP_VISIBLE) < 1:
            break
    
    cap.release()
    cv2.destroyAllWindows()

# Play the processed video
print("Playing processed video (press 'q' to quit)...")
play_video(output_video_path)
# Out:
# Select ROI and press ENTER. Press C to cancel.
#
# video 1/1 (frame 1/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 24.6ms
# video 1/1 (frame 2/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 15.6ms
# video 1/1 (frame 3/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 15.2ms
# video 1/1 (frame 4/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 20.8ms
# video 1/1 (frame 5/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 16.0ms
# video 1/1 (frame 6/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 22.1ms
# video 1/1 (frame 7/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 16.1ms
# video 1/1 (frame 8/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 13.3ms
# video 1/1 (frame 9/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 21.2ms
# video 1/1 (frame 10/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 20.5ms
# video 1/1 (frame 11/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 15.3ms
# video 1/1 (frame 12/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 15.9ms
# video 1/1 (frame 13/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 23.2ms
# video 1/1 (frame 14/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 21.8ms
# video 1/1 (frame 15/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 17.7ms
# video 1/1 (frame 16/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 18.1ms
# video 1/1 (frame 17/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 23.3ms
# video 1/1 (frame 18/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 15.8ms
# video 1/1 (frame 19/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 17.3ms
# video 1/1 (frame 20/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 20.0ms
# video 1/1 (frame 21/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 18.3ms
# video 1/1 (frame 22/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 15.4ms
# video 1/1 (frame 23/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 14.2ms
# video 1/1 (frame 24/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 13.1ms
# video 1/1 (frame 25/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 17.4ms
# video 1/1 (frame 26/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 30 obs, 13.0ms
# video 1/1 (frame 27/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 30 obs, 21.2ms
# video 1/1 (frame 28/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 30 obs, 20.6ms
# video 1/1 (frame 29/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 16.5ms
# video 1/1 (frame 30/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 15.7ms
# video 1/1 (frame 31/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 22.7ms
# video 1/1 (frame 32/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 23.1ms
# video 1/1 (frame 33/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 22.8ms
# video 1/1 (frame 34/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 17.3ms
# video 1/1 (frame 35/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 29 obs, 14.0ms
# video 1/1 (frame 36/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 17.9ms
# video 1/1 (frame 37/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 18.6ms
# video 1/1 (frame 38/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 27 obs, 23.8ms
# video 1/1 (frame 39/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 26 obs, 18.9ms
# video 1/1 (frame 40/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 25 obs, 22.2ms
# video 1/1 (frame 41/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 26 obs, 22.0ms
# video 1/1 (frame 42/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 26 obs, 13.9ms
# video 1/1 (frame 43/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 26 obs, 18.5ms
# video 1/1 (frame 44/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 25 obs, 24.2ms
# video 1/1 (frame 45/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 26 obs, 21.8ms
# video 1/1 (frame 46/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 26 obs, 22.4ms
# video 1/1 (frame 47/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 26 obs, 22.1ms
# video 1/1 (frame 48/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 25 obs, 22.9ms
# video 1/1 (frame 49/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 25 obs, 13.7ms
# video 1/1 (frame 50/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 25 obs, 23.9ms
# video 1/1 (frame 51/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 25 obs, 13.2ms
# video 1/1 (frame 52/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 24 obs, 23.1ms
# video 1/1 (frame 53/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 24 obs, 20.3ms
# video 1/1 (frame 54/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 24 obs, 21.0ms
# video 1/1 (frame 55/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 24 obs, 19.1ms
# video 1/1 (frame 56/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 24 obs, 19.7ms
# video 1/1 (frame 57/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 24 obs, 23.0ms
# video 1/1 (frame 58/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 25 obs, 19.6ms
# video 1/1 (frame 59/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 25 obs, 21.4ms
# video 1/1 (frame 60/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 25 obs, 20.1ms
# video 1/1 (frame 61/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 24 obs, 16.2ms
# video 1/1 (frame 62/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 24 obs, 12.5ms
# video 1/1 (frame 63/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 26 obs, 17.3ms
# video 1/1 (frame 64/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 27 obs, 20.0ms
# video 1/1 (frame 65/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 26 obs, 16.8ms
# video 1/1 (frame 66/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 26 obs, 14.0ms
# video 1/1 (frame 67/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 26 obs, 16.0ms
# video 1/1 (frame 68/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 26 obs, 18.5ms
# video 1/1 (frame 69/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 26 obs, 17.8ms
# video 1/1 (frame 70/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 26 obs, 23.3ms
# video 1/1 (frame 71/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 27 obs, 21.1ms
# video 1/1 (frame 72/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 24 obs, 13.1ms
# video 1/1 (frame 73/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 24 obs, 13.2ms
# video 1/1 (frame 74/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 24 obs, 18.7ms
# video 1/1 (frame 75/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 22 obs, 25.6ms
# video 1/1 (frame 76/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 22 obs, 13.7ms
# video 1/1 (frame 77/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 22 obs, 25.9ms
# video 1/1 (frame 78/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 22 obs, 17.1ms
# video 1/1 (frame 79/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 22 obs, 22.0ms
# video 1/1 (frame 80/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 22 obs, 15.2ms
# video 1/1 (frame 81/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 22 obs, 20.6ms
# video 1/1 (frame 82/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 22 obs, 11.7ms
# video 1/1 (frame 83/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 22 obs, 19.6ms
# video 1/1 (frame 84/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 22 obs, 13.8ms
# video 1/1 (frame 85/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 22 obs, 24.6ms
# video 1/1 (frame 86/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 22 obs, 12.8ms
# video 1/1 (frame 87/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 22 obs, 20.1ms
# video 1/1 (frame 88/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 22 obs, 23.1ms
# video 1/1 (frame 89/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 22 obs, 12.2ms
# video 1/1 (frame 90/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 22 obs, 14.4ms
# video 1/1 (frame 91/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 22 obs, 16.8ms
# video 1/1 (frame 92/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 21 obs, 24.3ms
# video 1/1 (frame 93/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 21 obs, 15.1ms
# video 1/1 (frame 94/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 19 obs, 16.1ms
# video 1/1 (frame 95/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 19 obs, 22.9ms
# video 1/1 (frame 96/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 19 obs, 16.0ms
# video 1/1 (frame 97/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 19 obs, 16.9ms
# video 1/1 (frame 98/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 19 obs, 19.2ms
# video 1/1 (frame 99/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 21 obs, 15.7ms
# video 1/1 (frame 100/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 21 obs, 16.9ms
# video 1/1 (frame 101/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 23 obs, 15.2ms
# video 1/1 (frame 102/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 23 obs, 17.3ms
# video 1/1 (frame 103/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 25 obs, 21.4ms
# video 1/1 (frame 104/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 26 obs, 11.0ms
# video 1/1 (frame 105/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 26 obs, 19.2ms
# video 1/1 (frame 106/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 26 obs, 24.8ms
# video 1/1 (frame 107/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 17.6ms
# video 1/1 (frame 108/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 22.2ms
# video 1/1 (frame 109/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 21.0ms
# video 1/1 (frame 110/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 12.8ms
# video 1/1 (frame 111/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 11.2ms
# video 1/1 (frame 112/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 22.3ms
# video 1/1 (frame 113/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 13.5ms
# video 1/1 (frame 114/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 21.7ms
# video 1/1 (frame 115/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 24.0ms
# video 1/1 (frame 116/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 17.6ms
# video 1/1 (frame 117/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 20.7ms
# video 1/1 (frame 118/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 20.5ms
# video 1/1 (frame 119/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 21.3ms
# video 1/1 (frame 120/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 20.7ms
# video 1/1 (frame 121/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 16.1ms
# video 1/1 (frame 122/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 13.8ms
# video 1/1 (frame 123/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 17.9ms
# video 1/1 (frame 124/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 18.6ms
# video 1/1 (frame 125/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 14.6ms
# video 1/1 (frame 126/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 23.4ms
# video 1/1 (frame 127/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 20.4ms
# video 1/1 (frame 128/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 18.7ms
# video 1/1 (frame 129/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 25.2ms
# video 1/1 (frame 130/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 15.1ms
# video 1/1 (frame 131/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 20.3ms
# video 1/1 (frame 132/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 20.2ms
# video 1/1 (frame 133/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 20.0ms
# video 1/1 (frame 134/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 23.3ms
# video 1/1 (frame 135/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 12.5ms
# video 1/1 (frame 136/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 8.5ms
# video 1/1 (frame 137/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 14.2ms
# video 1/1 (frame 138/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 14.5ms
# video 1/1 (frame 139/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 14.0ms
# video 1/1 (frame 140/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 9.3ms
# video 1/1 (frame 141/141) C:\Users\joshu\Queen's University Belfast\Michael Loughran - 20241213_ml_bad\20241213_120604_BL7.mp4: 384x640 28 obs, 14.2ms
# Speed: 1.6ms preprocess, 18.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed video saved to C:\Users\joshu\Documents\EEE\AMNIS\output_videos\heatmap.mp4
# Playing processed video (press 'q' to quit)...

# %%
from ultralytics import YOLO
import cv2
import os
import time

def iou(boxA, boxB):
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])
    interArea = max(0, xB - xA) * max(0, yB - yA)  # Area of intersection
    boxAArea = (boxA[2] - boxA[0]) * (boxA[3] - boxA[1])  # Area of boxA
    boxBArea = (boxB[2] - boxB[0]) * (boxB[3] - boxB[1])  # Area of boxB
    if boxAArea == 0 or boxBArea == 0:
        return 0.0
    return interArea / float(boxAArea + boxBArea - interArea)

MAX_THUMBNAIL_WIDTH = 100

def overlay_object_images(frame, objects_that_left, object_images):
    height, width = frame.shape[:2]
    img_offset = 10
    
    y_start = height  # Start from bottom and go upwards

    for idx, lbl in enumerate(objects_that_left):
        if lbl in object_images:
            try:
                obj_img = object_images[lbl]
                if obj_img is None or obj_img.size == 0:
                    continue
                
                # Calculate the aspect ratio
                orig_h, orig_w = obj_img.shape[:2]
                scale = MAX_THUMBNAIL_WIDTH / float(orig_w)
                
                new_w = int(orig_w * scale)
                new_h = int(orig_h * scale)
                
                # Resize with same aspect ratio
                obj_img_resized = cv2.resize(obj_img, (new_w, new_h))
                
                # Now compute top-left corner so the thumbnail is placed above the previous one
                # Let's assume y_start decreases by new_h + offset each iteration
                y_start -= (new_h + img_offset)
                x_start = width - (new_w + img_offset)
                
                # Bounds check
                if x_start < 0 or y_start < 0:
                    continue
                
                # Overlay the object image
                frame[y_start:y_start+new_h, x_start:x_start+new_w] = obj_img_resized
                
                # Add label text above the thumbnail
                cv2.putText(frame, f"Object {lbl}",
                            (x_start, y_start - 5),
                            cv2.FONT_HERSHEY_SIMPLEX, 
                            0.5, 
                            (255, 255, 255),
                            1)
            
            except Exception as e:
                print(f"Error processing object {lbl}: {str(e)}")
                continue
    
    return frame

# ------------------------------------------------------------
# Configuration
# ------------------------------------------------------------
model_path = r"C:\Users\joshu\Documents\EEE\AMNIS\Models\training\weights\best.pt"
video_path = r"C:\Users\joshu\Downloads\start_end_cornflakes.mp4"
save_dir = r"C:\Users\joshu\Documents\EEE\AMNIS\output_videos"
os.makedirs(save_dir, exist_ok=True)

# Detection thresholds
detection_conf_thresh = 0.4   # Confidence threshold for YOLO detections
detection_nms_thresh = 0.05   # NMS IOU threshold for YOLO detections

# Tracking thresholds
tracking_iou_thresh = 0.5     # IOU threshold for object tracking/matching
shelf_thresh = 100           # Vertical distance threshold for shelf grouping
lost_time_limit = 500        # Frames before declaring object as permanently lost

tracker_config = 'bytetrack.yaml'

# Initialize video capture to get frame for ROI selection
cap = cv2.VideoCapture(video_path)
ret, first_frame = cap.read()
if not ret:
    raise RuntimeError("Could not read first frame")

# Get ROI from user
print("Select ROI and press ENTER. Press C to cancel.")
roi = cv2.selectROI("Select ROI", first_frame, fromCenter=False, showCrosshair=True)
cv2.destroyWindow("Select ROI")
x_min, y_min, w, h = roi
x_max, y_max = x_min + w, y_min + h

# Get video properties
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
cap.release()

# Load YOLO model
model = YOLO(model_path)

# Initialize the tracking generator
generator = model.track(
    source=video_path,
    imgsz=640,
    conf=detection_conf_thresh,
    iou=detection_nms_thresh,
    tracker=tracker_config,
    stream=True
)

# Prepare video writer
output_video_path = os.path.join(save_dir, "cornflakes.mp4")
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out_writer = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

# State management
active_objects = []      # List of (label, box) tuples for current objects
lost_objects = {}        # Dict of label: (box, last_seen_frame) for lost objects
next_label_num = 1      # Counter for generating unique object labels
objects_that_left = set()  # Set of labels for objects that have left the scene
frame_count = 0
box_color = (0, 255, 0)
object_first_seen = {}  # Dictionary to store the first frame and bounding box of each object
object_images = {}      # Dictionary to store object images for display
last_valid_images = {}  # Dictionary to store the last valid image of each object

# Main processing loop
while True:
    try:
        results = next(generator)
    except StopIteration:
        break

    frame_count += 1
    frame = results.orig_img.copy()

    # Filter boxes to only include those within ROI
    boxes = []
    for b in results.boxes:
        x1, y1, x2, y2 = map(int, b.xyxy[0])
        if (x_min <= x1 <= x_max and x_min <= x2 <= x_max and
            y_min <= y1 <= y_max and y_min <= y2 <= y_max):
            boxes.append((x1, y1, x2, y2))

    if boxes:
        # Group boxes into shelves
        boxes.sort(key=lambda b: b[3])
        shelves = []
        for bx in boxes:
            x1, y1, x2, y2 = bx
            placed = False
            for shelf in shelves:
                shelf_bottoms = [b[3] for b in shelf]
                shelf_mean_bottom = sum(shelf_bottoms) / len(shelf_bottoms)
                if abs(y2 - shelf_mean_bottom) <= shelf_thresh:
                    shelf.append(bx)
                    placed = True
                    break
            if not placed:
                shelves.append([bx])

        # Sort shelves and create final box list
        for shelf in shelves:
            shelf.sort(key=lambda b: b[0])
        sorted_boxes = [b for shelf in shelves for b in shelf]

        # Track objects
        new_objects = []
        used_active_labels = set()

        for new_box in sorted_boxes:
            # Try to match with active objects
            best_iou = 0
            best_label = None
            for (lbl, a_box) in active_objects:
                iou_val = iou(a_box, new_box)
                if iou_val > best_iou:
                    best_iou = iou_val
                    best_label = lbl

            if best_iou > tracking_iou_thresh:
                new_objects.append((best_label, new_box))
                used_active_labels.add(best_label)
                # Store the current image of the object while it's still visible
                x1, y1, x2, y2 = new_box
                if y1 < frame.shape[0] and y2 < frame.shape[0] and x1 < frame.shape[1] and x2 < frame.shape[1]:
                    last_valid_images[best_label] = frame[y1:y2, x1:x2].copy()
            else:
                # Assign a new label
                new_objects.append((next_label_num, new_box))
                object_first_seen[next_label_num] = (frame_count, new_box)
                # Store initial image of new object
                x1, y1, x2, y2 = new_box
                if y1 < frame.shape[0] and y2 < frame.shape[0] and x1 < frame.shape[1] and x2 < frame.shape[1]:
                    last_valid_images[next_label_num] = frame[y1:y2, x1:x2].copy()
                used_active_labels.add(next_label_num)
                next_label_num += 1

        # Handle disappeared objects
        active_labels = {lbl for (lbl, _) in active_objects}
        disappeared = active_labels - used_active_labels
        for lbl in disappeared:
            for (l, box) in active_objects:
                if l == lbl:
                    lost_objects[lbl] = (box, frame_count)
                    objects_that_left.add(lbl)
                    
                    # Use the last valid image we stored
                    if lbl in last_valid_images:
                        object_images[lbl] = last_valid_images[lbl]
                        # Optionally save to disk
                        image_path = os.path.join(save_dir, f"object_{lbl}.png")
                        cv2.imwrite(image_path, last_valid_images[lbl])
                        print(f"Saved image for object {lbl} at {image_path}")

        # Clean up lost objects
        lost_objects = {
            lbl: (box, frame) 
            for lbl, (box, frame) in lost_objects.items() 
            if frame_count - frame <= lost_time_limit
        }

        active_objects = new_objects

        # Draw visualizations
        # Draw ROI
        cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), (255, 0, 0), 2)

        # Draw bounding boxes and labels
        for (lbl, (x1, y1, x2, y2)) in active_objects:
            cv2.rectangle(frame, (x1, y1), (x2, y2), box_color, 2)
            cv2.putText(frame, f"{lbl}", (x1 + 5, y1 + 20), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.7, box_color, 2)

        # Draw shelf boundaries
        for idx, shelf in enumerate(shelves, start=1):
            y = min(b[3] for b in shelf)
            cv2.line(frame, (0, y), (width, y), (0, 0, 255), 2)
            cv2.putText(frame, f"Shelf {idx}", (10, y - 10), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

        # Use the overlay_object_images function
        frame = overlay_object_images(frame, objects_that_left, object_images)

        # Draw status information
        if objects_that_left:
            text = f"Objects that have left: {', '.join(map(str, objects_that_left))}"
            cv2.putText(frame, text, (100, 90), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)

        cv2.putText(frame, f"Total objects in scene: {len(active_objects)}", 
                   (100, 45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    else:
        # Handle case when no boxes are detected
        for (lbl, box) in active_objects:
            lost_objects[lbl] = (box, frame_count)
            objects_that_left.add(lbl)
        active_objects = []

    out_writer.write(frame)

cap.release()
out_writer.release()
print(f"Processed video saved to {output_video_path}")

# Play the processed video
def play_video(video_path):
    cap = cv2.VideoCapture(video_path)
    
    # Get video properties
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    frame_delay = int(1000/fps)  # Convert fps to milliseconds delay between frames
    
    while True:
        ret, frame = cap.read()
        if not ret:
            break
            
        cv2.imshow('Processed Video', frame)
        
        # Break loop if 'q' is pressed or window is closed
        key = cv2.waitKey(frame_delay) & 0xFF
        if key == ord('q') or cv2.getWindowProperty('Processed Video', cv2.WND_PROP_VISIBLE) < 1:
            break
    
    cap.release()
    cv2.destroyAllWindows()

# Play the processed video
print("Playing processed video (press 'q' to quit)...")
play_video(output_video_path)
# Out:
# Select ROI and press ENTER. Press C to cancel.
#
# video 1/1 (frame 1/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 33.5ms
# video 1/1 (frame 2/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 9.5ms
# video 1/1 (frame 3/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.5ms
# video 1/1 (frame 4/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 9.0ms
# video 1/1 (frame 5/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.0ms
# video 1/1 (frame 6/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.5ms
# video 1/1 (frame 7/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 7.5ms
# video 1/1 (frame 8/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 17.5ms
# video 1/1 (frame 9/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.5ms
# video 1/1 (frame 10/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.0ms
# video 1/1 (frame 11/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 7.9ms
# video 1/1 (frame 12/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 7.0ms
# video 1/1 (frame 13/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 10.5ms
# video 1/1 (frame 14/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.5ms
# video 1/1 (frame 15/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.5ms
# video 1/1 (frame 16/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.0ms
# video 1/1 (frame 17/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.0ms
# video 1/1 (frame 18/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 9.2ms
# video 1/1 (frame 19/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 7.5ms
# video 1/1 (frame 20/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.5ms
# video 1/1 (frame 21/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 7.5ms
# video 1/1 (frame 22/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 7.5ms
# video 1/1 (frame 23/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 7.5ms
# video 1/1 (frame 24/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 7.5ms
# video 1/1 (frame 25/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.5ms
# video 1/1 (frame 26/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.5ms
# video 1/1 (frame 27/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.0ms
# video 1/1 (frame 28/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 7.5ms
# video 1/1 (frame 29/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 7.0ms
# video 1/1 (frame 30/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 7.0ms
# video 1/1 (frame 31/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.5ms
# video 1/1 (frame 32/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 7.6ms
# video 1/1 (frame 33/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 7.5ms
# video 1/1 (frame 34/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.1ms
# video 1/1 (frame 35/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 7.5ms
# video 1/1 (frame 36/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 7.5ms
# video 1/1 (frame 37/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.5ms
# video 1/1 (frame 38/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 7.5ms
# video 1/1 (frame 39/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.0ms
# video 1/1 (frame 40/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 7.5ms
# video 1/1 (frame 41/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 7.5ms
# video 1/1 (frame 42/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.5ms
# video 1/1 (frame 43/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.4ms
# video 1/1 (frame 44/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 7.5ms
# video 1/1 (frame 45/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.0ms
# video 1/1 (frame 46/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 7.5ms
# video 1/1 (frame 47/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.5ms
# video 1/1 (frame 48/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.0ms
# video 1/1 (frame 49/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 8.0ms
# video 1/1 (frame 50/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 30 obs, 7.0ms
# video 1/1 (frame 51/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 7.6ms
# Saved image for object 19 at C:\Users\joshu\Documents\EEE\AMNIS\output_videos\object_19.png
# video 1/1 (frame 52/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 8.0ms
# video 1/1 (frame 53/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 16.0ms
# video 1/1 (frame 54/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 7.5ms
# video 1/1 (frame 55/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 8.5ms
# video 1/1 (frame 56/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 7.5ms
# video 1/1 (frame 57/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 7.5ms
# video 1/1 (frame 58/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 8.0ms
# video 1/1 (frame 59/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 7.6ms
# video 1/1 (frame 60/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 7.5ms
# video 1/1 (frame 61/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 7.5ms
# video 1/1 (frame 62/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 7.5ms
# video 1/1 (frame 63/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 8.0ms
# video 1/1 (frame 64/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 7.8ms
# video 1/1 (frame 65/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 7.0ms
# video 1/1 (frame 66/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 8.0ms
# video 1/1 (frame 67/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 8.2ms
# video 1/1 (frame 68/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 7.5ms
# video 1/1 (frame 69/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 7.5ms
# video 1/1 (frame 70/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 7.5ms
# video 1/1 (frame 71/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 8.5ms
# video 1/1 (frame 72/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 8.5ms
# video 1/1 (frame 73/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 9.1ms
# video 1/1 (frame 74/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 8.0ms
# video 1/1 (frame 75/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 10.5ms
# video 1/1 (frame 76/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 8.5ms
# video 1/1 (frame 77/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 8.0ms
# video 1/1 (frame 78/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 8.0ms
# video 1/1 (frame 79/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 7.5ms
# video 1/1 (frame 80/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 7.5ms
# video 1/1 (frame 81/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 7.7ms
# video 1/1 (frame 82/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 8.5ms
# video 1/1 (frame 83/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 8.5ms
# video 1/1 (frame 84/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 8.5ms
# video 1/1 (frame 85/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 8.5ms
# video 1/1 (frame 86/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 9.0ms
# video 1/1 (frame 87/87) C:\Users\joshu\Downloads\start_end_cornflakes.mp4: 384x640 29 obs, 9.4ms
# Speed: 1.0ms preprocess, 8.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed video saved to C:\Users\joshu\Documents\EEE\AMNIS\output_videos\cornflakes.mp4
# Playing processed video (press 'q' to quit)...
